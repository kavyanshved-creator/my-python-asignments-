# %%
"""1.
Create three variables in Python named item_price, delivery_fee,
and coupon_discount, and assign them values representing a Swiggy order
(e.g., 250, 30, 20). Print each variable.

2.
Write a Python script that uses indentation correctly to check if a 
Flipkart product's price is above 1000; if yes, print 'Eligible for 
free delivery', else print 'Delivery charges apply'.<br><br><em><strong>Hint:</strong>
Use an if-else block and make sure your indentation is consistent.</em>

3.
Add both single-line and multi-line comments in your script explaining what 
each section does, using # for single-line and triple quotes for multi-line comments.

4.
Create variables for an IPL match: team_name, runs_scored, and overs_played.
Assign appropriate values and print them using the correct naming conventions for Python 
variables.<br><br><em><strong>Constraint:</strong> Use snake_case for all variable names.</em>"""

# %%
"""1.
Create three variables in Python named item_price, delivery_fee,
and coupon_discount, and assign them values representing a Swiggy order
(e.g., 250, 30, 20). Print each variable."""

item_price = 450
delivery_fee = 50
coupon_discount = 10

print(item_price)
print(delivery_fee)
print(coupon_discount)
# Out:
# 450
# 50
# 10

# %%
"""2.
Write a Python script that uses indentation correctly to check if a 
Flipkart product's price is above 1000; if yes, print 'Eligible for 
free delivery', else print 'Delivery charges apply'.<br><br><em><strong>Hint:</strong>
Use an if-else block and make sure your indentation is consistent.</em>"""

product_prices = int(input("Enter product price : "))

if product_prices > 1000 :
    print ("Eligible for free delivery")
else:
    print("Delivery charges apply")
# Out:
# Eligible for free delivery

# %%
"""3.
Add both single-line and multi-line comments in your script explaining what 
each section does, using # for single-line and triple quotes for multi-line comments.
"""

"""
This section demonstrates how to use comments in Python.
The script stores order details and prints them for review.
"""

# Store the price of the item.
item_price = 450

# Store the delivery fee charged for the order.
delivery_fee = 50

# Store the discount amount applied to the order.
coupon_discount = 10

# Print each order value.
print(item_price)
print(delivery_fee)
print(coupon_discount)
# Out:
# 450
# 50
# 10

# %%
"""4.
Create variables for an IPL match: team_name, runs_scored, and overs_played.
Assign appropriate values and print them using the correct naming conventions for Python 
variables.<br><br><em><strong>Constraint:</strong> Use snake_case for all variable names.</em>
"""

team_name = "Chennai Super Kings"
runs_scored = 185
overs_played = 20

print(team_name)
print(runs_scored)
print(overs_played)
# Out:
# Chennai Super Kings
# 185
# 20

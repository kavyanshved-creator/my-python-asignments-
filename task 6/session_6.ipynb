# %%
"""1.
Create a Python dictionary called insta_followers that stores the 
number of followers for 5 Instagram influencers 
(use their usernames as keys and follower counts as values). Print the dictionary.
2.
Add a new influencer to your insta_followers dictionary and 
update the follower count for one existing influencer. Then,
delete one influencer from the dictionary and print the updated dictionary.
3.
Given a dictionary called food_prices with 5 Zomato food items 
as keys and their prices as values, write code to display all items 
that cost more than ₹200.
4.
Create two sets: flipkart_users and myntra_users, each containing 
5 unique usernames. Find and print the set of users who have accounts 
on both platforms using set intersection.
5.
Write a function get_unique_artists(spotify_playlist1, spotify_playlist2)
that takes two sets of artist names and returns a set of all unique artists
across both playlists (set union).<br><br><em><strong>Hint:</strong> Use the 
union() method or the | operator for sets.</em>
"""

# %%
"""1.
Create a Python dictionary called insta_followers that stores the
number of followers for 5 Instagram influencers. Use their usernames
as keys and follower counts as values, then print the dictionary."""

insta_followers = {
    "@virat.kohli": 273.3,
    "@narendramodi": 101.9,
    "@shraddhakapoor": 93.3,
    "@priyankachopra": 93.0,
    "@aliaabhatt": 85.7,
}

print(insta_followers)
# Out:
# {'@virat.kohli': 273.3, '@narendramodi': 101.9, '@shraddhakapoor': 93.3, '@priyankachopra': 93.0, '@aliaabhatt': 85.7}

# %%
"""2.
Add a new influencer to your insta_followers dictionary and 
update the follower count for one existing influencer. Then,
delete one influencer from the dictionary and print the updated dictionary."""

insta_followers = {
    "@virat.kohli": 273.3,
    "@narendramodi": 101.9,
    "@shraddhakapoor": 93.3,
    "@priyankachopra": 93.0,
    "@aliaabhatt": 85.7,
}
print(insta_followers)

insta_followers["@vijaydevrkonda"] = 98.5        # it adds a new influencer
print(insta_followers)

insta_followers["@virat.kohli"] = 444.4           # this will update the value of virat kohli
print(insta_followers)

del insta_followers["@shraddhakapoor"]              # this will delete the @shraddhakapoor data in dictionary
print(insta_followers)
# Out:
# {'@virat.kohli': 273.3, '@narendramodi': 101.9, '@shraddhakapoor': 93.3, '@priyankachopra': 93.0, '@aliaabhatt': 85.7}
# {'@virat.kohli': 273.3, '@narendramodi': 101.9, '@shraddhakapoor': 93.3, '@priyankachopra': 93.0, '@aliaabhatt': 85.7, '@vijaydevrkonda': 98.5}
# {'@virat.kohli': 444.4, '@narendramodi': 101.9, '@shraddhakapoor': 93.3, '@priyankachopra': 93.0, '@aliaabhatt': 85.7, '@vijaydevrkonda': 98.5}
# {'@virat.kohli': 444.4, '@narendramodi': 101.9, '@priyankachopra': 93.0, '@aliaabhatt': 85.7, '@vijaydevrkonda': 98.5}

# %%
"""
3.
Given a dictionary called food_prices with 5 Zomato food items 
as keys and their prices as values, write code to display all items 
that cost more than ₹200.
"""
food_prices = {
    "paneer tikka": 220,
    "malai Kofta": 180,
    "pizza": 450,
    "biryani": 320,
    "dosa": 120
}

for item, price in food_prices.items():
    if price > 200:
        print(item, price)
# Out:
# paneer tikka 220
# pizza 450
# biryani 320

# %%
"""4.
Create two sets: flipkart_users and myntra_users, each containing
5 unique usernames. Find and print the set of users who have accounts
on both platforms using set intersection."""

flipkart_users = {
    "Nimesh",
    "Rahul",
    "Priya",
    "Anita",
    "Vikram"
}

myntra_users = {
    "Priya",
    "Anita",
    "Sanjay",
    "Neha",
    "Amit"
}

common_users = flipkart_users.intersection(myntra_users)
print(common_users)
# Out:
# {'Priya', 'Anita'}

# %%
"""5.
Write a function get_unique_artists(spotify_playlist1, spotify_playlist2)
that takes two sets of artist names and returns a set of all unique artists
across both playlists (set union).<br><br><em><strong>Hint:</strong> Use the 
union() method or the | operator for sets.</em>"""

def get_unique_artists(spotify_playlist1, spotify_playlist2):
    return spotify_playlist1.union(spotify_playlist2)


playlist1 = {"Arijit Singh", "Atif Aslam", "A.R. Rahman"}
playlist2 = {"Arijit Singh", "Shreya Ghoshal", "A.R. Rahman"}

unique_artists = get_unique_artists(playlist1, playlist2)

print(unique_artists)
# Out:
# {'Arijit Singh', 'Atif Aslam', 'A.R. Rahman', 'Shreya Ghoshal'}
